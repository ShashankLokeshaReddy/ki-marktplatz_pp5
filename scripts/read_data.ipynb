# %%
import pandas as pd
from pandas_ods_reader import read_ods
import numpy as np
import datetime as datetime
import re

# %% [markdown]
# # Datenvorverarbeitung

# %%
path = "../data/Arbeitsplanung_steuerung_Wickelmaschinen_alt.ods"
sheet_idx = 14
df = read_ods(path, sheet_idx)
df = df.rename(columns=df.iloc[10])
df = df.rename(columns={df.columns[0]:'Nichts'})
df = df.drop('Nichts', axis=1)
df = df.drop(np.arange(12))
df = df.reset_index(drop=True)
df = df[['Fertigungsauf-tragsnummer', 'Teilenummer', 
         'Auftragsmenge',  'Nummer Wickel-rohrmaschine', 'Werkzeug-nummer', 'Rüstzeit für WKZ/Materialwechsel', 'Rüstzeit für Coilwechsel', 'Maschinen-laufzeit', 'Fertigungszeit pro Mengeneinheit']]
df
# Out:
#    Fertigungsauf-tragsnummer     Teilenummer Auftragsmenge Auftragsmenge  \
# 0              92021412719.0       60PAP2060        1000.0           0.0
# 1              92021529395.0       70AA30000        3000.0          34.0
# 2              92021529919.0           80PAK        3000.0          24.0
# 3              92021530000.0        90APK004        3000.0          20.0
# 4              92021539118.0       55PAP3985         480.0          20.0
# 5              92021539115.0       55PAP1140         300.0          20.0
# 6              92021640739.0       55PAP0450         500.0           0.0
# 7              92021640740.0       55PAP0540         300.0           0.0
# 8              92021641265.0       80APK1401          21.0           0.0
# 9              92021640738.0       55PAP0060         480.0           0.0
# 10             92021641264.0       80APK1360          21.0           0.0
# 11             92021641262.0       80APK0890          21.0           0.0
# 12             92021640762.0       60APK0420          12.0           0.0
# 13             92021631408.0           70PAK           0.0          56.0
# 14             92021641106.0       75APK1000         240.0           0.0
# 15             92021641115.0       75APK1201         120.0           0.0
# 16             92021641114.0       75APK1100         120.0           0.0
# 17             92021631991.0       90PAPK002           0.0          20.0
# 18             92021631418.0        70PAK001           0.0          18.0
# 19             92021529585.0           75APK           0.0          40.0
# 20             92021640902.0        63AA0420           3.0           0.0
# 21             92021529110.0        60APK009           0.0           6.0
# 22             92021529592.0        75APK001           0.0           6.0
# 23             92021640616.0       50AA61200           6.0           6.0
# 24             92021730626.0        60APK009           0.0           6.0
# 25             92021741249.0       75APK1501         500.0           0.0
# 26             92021741234.0       75APK1000         120.0           0.0
# 27             92021731633.0       90PAPK003           0.0          31.0
# 28             92021741254.0       75APK4200          31.0           0.0
# 29             92021730909.0           65PAK           0.0           1.0
# 30             92021731105.0           75APK           0.0          40.0
# 31             92021734176.0       130AA0700          15.0           0.0
# 32             92021730922.0       70AA30000           0.0          34.0
# 33             92021731126.0      75APK20000           0.0          21.0
# 34             92021731122.0      75APK10000           0.0          24.0
# 35             92021730284.0           50AA6           0.0          60.0
# 36             92021740878.0  60APPBEIGE1701         500.0           0.0
# 37             92021730203.0       40APK1750         100.0           0.0
# 38             92021740714.0       50AA61001         120.0           0.0
# 39             12021034661.0           55APK           0.0           4.0
# 40             92021730764.0           60PAK           0.0          24.0
# 41             92021730789.0       60PAPK003           0.0          24.0
# 42             92021730590.0      55APK10000           0.0          16.0
# 43             92021740823.0        55AA0470          20.0           0.0
# 44             92021730275.0        50AA1500         700.0           0.0
# 45             92021740705.0        50AA1001          10.0           0.0
# 46             92021740867.0           60APK           0.0          72.0
# 47             92021726546.0       20AGA0476       11400.0           0.0
# 48             92021730629.0        60APK013           0.0          28.0
# 49             92021730235.0           45APK           0.0           5.0
#
#    Nummer Wickel-rohrmaschine Werkzeug-nummer  \
# 0     Wickelrohrmaschine 1531          A0 023
# 1     Wickelrohrmaschine 1531          A0 023
# 2     Wickelrohrmaschine 1531          A0 023
# 3     Wickelrohrmaschine 1531          A0 023
# 4     Wickelrohrmaschine 1535          A0 023
# 5     Wickelrohrmaschine 1535          A0 023
# 6     Wickelrohrmaschine 1536          A0 012
# 7     Wickelrohrmaschine 1537          A0 012
# 8     Wickelrohrmaschine 1531          A0 016
# 9     Wickelrohrmaschine 1535          A0 012
# 10    Wickelrohrmaschine 1531          A0 016
# 11    Wickelrohrmaschine 1531          A0 016
# 12    Wickelrohrmaschine 1533          A0 035
# 13    Wickelrohrmaschine 1531          A0 044
# 14    Wickelrohrmaschine 1531          A0 028
# 15    Wickelrohrmaschine 1531          A0 028
# 16    Wickelrohrmaschine 1531          A0 028
# 17    Wickelrohrmaschine 1531          A0 001
# 18    Wickelrohrmaschine 1531          A0 044
# 19    Wickelrohrmaschine 1531          A0 028
# 20    Wickelrohrmaschine 1531          A0 038
# 21    Wickelrohrmaschine 1532          A0 035
# 22    Wickelrohrmaschine 1531          A0 028
# 23    Wickelrohrmaschine 1536          A0 005
# 24    Wickelrohrmaschine 1533          A0 035
# 25    Wickelrohrmaschine 1531          A0 028
# 26    Wickelrohrmaschine 1531          A0 028
# 27    Wickelrohrmaschine 1531          A0 001
# 28    Wickelrohrmaschine 1531          A0 028
# 29    Wickelrohrmaschine 1531          A0 047
# 30    Wickelrohrmaschine 1531          A0 028
# 31    Wickelrohrmaschine 1531          A0 045
# 32    Wickelrohrmaschine 1531          A0 044
# 33    Wickelrohrmaschine 1531          A0 028
# 34    Wickelrohrmaschine 1531          A0 028
# 35    Wickelrohrmaschine 1537          A0 005
# 36    Wickelrohrmaschine 1533            None
# 37    Wickelrohrmaschine 1536          A0 006
# 38    Wickelrohrmaschine 1535          A0 005
# 39    Wickelrohrmaschine 1533          A0 012
# 40    Wickelrohrmaschine 1532          A0 035
# 41    Wickelrohrmaschine 1533          A0 035
# 42    Wickelrohrmaschine 1537          A0 012
# 43    Wickelrohrmaschine 1536          A0 012
# 44    Wickelrohrmaschine 1535          A0 005
# 45    Wickelrohrmaschine 1533          A0 005
# 46    Wickelrohrmaschine 1532          A0 035
# 47    Wickelrohrmaschine 1534          A0 024
# 48    Wickelrohrmaschine 1533          A0 035
# 49    Wickelrohrmaschine 1536          A0 007
#
#    Rüstzeit für WKZ/Materialwechsel Rüstzeit für Coilwechsel  \
# 0                              15.0                      2.0
# 1                              15.0                      2.0
# 2                              15.0                      2.0
# 3                              15.0                      2.0
# 4                              15.0                      2.0
# 5                              15.0                      2.0
# 6                              15.0                      2.0
# 7                              15.0                      2.0
# 8                              15.0                      2.0
# 9                              15.0                      2.0
# 10                             15.0                      2.0
# 11                             15.0                      2.0
# 12                             15.0                      2.0
# 13                             15.0                      2.0
# 14                             15.0                      2.0
# 15                             15.0                      2.0
# 16                             15.0                      2.0
# 17                             15.0                      2.0
# 18                             15.0                      2.0
# 19                             15.0                      2.0
# 20                             15.0                      2.0
# 21                             15.0                      2.0
# 22                             15.0                      2.0
# 23                             15.0                      2.0
# 24                             15.0                      2.0
# 25                             15.0                      2.0
# 26                             15.0                      2.0
# 27                             15.0                      2.0
# 28                             15.0                      2.0
# 29                             15.0                      2.0
# 30                             15.0                      2.0
# 31                             15.0                      2.0
# 32                             15.0                      2.0
# 33                             15.0                      2.0
# 34                             15.0                      2.0
# 35                             15.0                      2.0
# 36                             15.0                      2.0
# 37                             15.0                      2.0
# 38                             15.0                      2.0
# 39                             15.0                      2.0
# 40                             15.0                      2.0
# 41                             15.0                      2.0
# 42                             15.0                      2.0
# 43                             15.0                      2.0
# 44                             15.0                      2.0
# 45                             15.0                      2.0
# 46                             15.0                      2.0
# 47                             15.0                      2.0
# 48                             15.0                      2.0
# 49                             15.0                      2.0
#
#    Maschinen-laufzeit Fertigungszeit pro Mengeneinheit
# 0              323.96                             0.31
# 1              147.19                             3.89
# 2              124.49                             4.56
# 3              104.03                             4.45
# 4              570.94                             1.16
# 5               75.24                              0.2
# 6               53.32                             0.08
# 7               42.59                             0.09
# 8               19.68                             0.22
# 9                19.9                             0.01
# 10              19.55                             0.22
# 11              17.98                             0.14
# 12              15.66                             0.05
# 13             273.46                             4.62
# 14              55.77                             0.17
# 15              38.26                             0.19
# 16              36.32                             0.18
# 17              49.78                             1.74
# 18              79.87                              3.6
# 19             206.55                             4.79
# 20               15.2                             0.07
# 21             300.61                             47.6
# 22              34.39                             3.23
# 23               16.0                             0.17
# 24             243.21                            38.04
# 25             156.16                             0.28
# 26              34.39                             0.16
# 27             170.01                              5.0
# 28              36.03                             0.68
# 29              19.05                             4.05
# 30             206.55                             4.79
# 31              16.81                             0.12
# 32             203.27                             5.54
# 33              92.85                             3.71
# 34              55.77                              1.7
# 35             306.58                             4.86
# 36             #WERT!                           #WERT!
# 37              52.02                             0.37
# 38              31.73                             0.14
# 39              31.12                             4.03
# 40             121.28                             4.43
# 41             126.94                             4.66
# 42              40.79                             1.61
# 43              16.43                             0.07
# 44              190.9                             0.25
# 45              16.48                             0.15
# 46             357.73                             4.76
# 47            1669.83                             0.15
# 48              62.85                             1.71
# 49              41.33                             5.27

# %%
def parse_machine_number(df, column):
    """
    Function extracts the machine number of a expression in the format
    "Wickelrohrmaschine 1234" and gives back only the machines with a
    number expression.

    Parameters
    ----------
    df : pd.DataFrame
        dataframe with a column which contains a string expression
         for the machine
    column: string
        Name of the column that contains information about the machine

    Returns
    ---------
    pd.DataFrame
        Updated dataframe with new columns 'machine' and 'machine_id
    """
    #df = df[df.Nummer Wickel-rohrmaschine.str.startswith('Wickelrohrmaschine')]
    df['machine_id'] = df.apply(lambda row: str(row[column][-4:]).strip(),
                             axis=1)
    return df

# %%
df = parse_machine_number(df, 'Nummer Wickel-rohrmaschine')
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Anaconda3\envs\ki-marktplatz\lib\site-packages\pandas\core\indexes\base.py:3361, in Index.get_loc(self, key, method, tolerance)
#    3360 try:
# -> 3361     return self._engine.get_loc(casted_key)
#    3362 except KeyError as err:
#
# File D:\Anaconda3\envs\ki-marktplatz\lib\site-packages\pandas\_libs\index.pyx:76, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\Anaconda3\envs\ki-marktplatz\lib\site-packages\pandas\_libs\index.pyx:108, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Nummer Wickel-rohrmaschine'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [29], in <module>
# ----> 1 df = parse_machine_number(df, 'Nummer Wickel-rohrmaschine')
#       2 df
#
# Input In [22], in parse_machine_number(df, column)
#       2 """
#       3 Function extracts the machine number of a expression in the format
#       4 "Wickelrohrmaschine 1234" and gives back only the machines with a
#    (...)
#      18     Updated dataframe with new columns 'machine' and 'machine_id
#      19 """
#      20 #df = df[df.Nummer Wickel-rohrmaschine.str.startswith('Wickelrohrmaschine')]
# ---> 21 df['machine_id'] = df.apply(lambda row: str(row[column][-4:]).strip(),
#      22                          axis=1)
#      23 return df
#
# File D:\Anaconda3\envs\ki-marktplatz\lib\site-packages\pandas\core\frame.py:8740, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8729 from pandas.core.apply import frame_apply
#    8731 op = frame_apply(
#    8732     self,
#    8733     func=func,
#    (...)
#    8738     kwargs=kwargs,
#    8739 )
# -> 8740 return op.apply()
#
# File D:\Anaconda3\envs\ki-marktplatz\lib\site-packages\pandas\core\apply.py:688, in FrameApply.apply(self)
#     685 elif self.raw:
#     686     return self.apply_raw()
# --> 688 return self.apply_standard()
#
# File D:\Anaconda3\envs\ki-marktplatz\lib\site-packages\pandas\core\apply.py:812, in FrameApply.apply_standard(self)
#     811 def apply_standard(self):
# --> 812     results, res_index = self.apply_series_generator()
#     814     # wrap results
#     815     return self.wrap_results(results, res_index)
#
# File D:\Anaconda3\envs\ki-marktplatz\lib\site-packages\pandas\core\apply.py:828, in FrameApply.apply_series_generator(self)
#     825 with option_context("mode.chained_assignment", None):
#     826     for i, v in enumerate(series_gen):
#     827         # ignore SettingWithCopy here in case the user mutates
# --> 828         results[i] = self.f(v)
#     829         if isinstance(results[i], ABCSeries):
#     830             # If we have a view on v, we need to make a copy because
#     831             #  series_generator will swap out the underlying data
#     832             results[i] = results[i].copy(deep=False)
#
# Input In [22], in parse_machine_number.<locals>.<lambda>(row)
#       2 """
#       3 Function extracts the machine number of a expression in the format
#       4 "Wickelrohrmaschine 1234" and gives back only the machines with a
#    (...)
#      18     Updated dataframe with new columns 'machine' and 'machine_id
#      19 """
#      20 #df = df[df.Nummer Wickel-rohrmaschine.str.startswith('Wickelrohrmaschine')]
# ---> 21 df['machine_id'] = df.apply(lambda row: str(row[column][-4:]).strip(),
#      22                          axis=1)
#      23 return df
#
# File D:\Anaconda3\envs\ki-marktplatz\lib\site-packages\pandas\core\series.py:942, in Series.__getitem__(self, key)
#     939     return self._values[key]
#     941 elif key_is_scalar:
# --> 942     return self._get_value(key)
#     944 if is_hashable(key):
#     945     # Otherwise index.get_value will raise InvalidIndexError
#     946     try:
#     947         # For labels that don't resolve as scalars like tuples and frozensets
#
# File D:\Anaconda3\envs\ki-marktplatz\lib\site-packages\pandas\core\series.py:1051, in Series._get_value(self, label, takeable)
#    1048     return self._values[label]
#    1050 # Similar to Index.get_value, but we do not fall back to positional
# -> 1051 loc = self.index.get_loc(label)
#    1052 return self.index._get_values_for_loc(self, loc, label)
#
# File D:\Anaconda3\envs\ki-marktplatz\lib\site-packages\pandas\core\indexes\base.py:3363, in Index.get_loc(self, key, method, tolerance)
#    3361         return self._engine.get_loc(casted_key)
#    3362     except KeyError as err:
# -> 3363         raise KeyError(key) from err
#    3365 if is_scalar(key) and isna(key) and not self.hasnans:
#    3366     raise KeyError(key)
#
# KeyError: 'Nummer Wickel-rohrmaschine'

# %%
def calculate_setup_time(tool1, tool2):
    if tool1 == tool2:
        setup_time = 0
    else:
        setup_time = 15
    return setup_time

def calculate_timestamps(df, start, last_tool):
    machines = df['machine_id'].astype(int).unique()
    df = df.assign(starttime=0)
    df = df.assign(endtime=0)
    df = df.assign(setup_time=0)
    # Für jede Maschine 
    for machine in machines:
        df_machine = df[df['machine_id'] == str(machine)]
        timestamp = start
        # Entsprechend der Reihenfolge timestamps berechnen
        for index, row in df_machine.iterrows():
            order_num = row['Fertigungsauf-tragsnummer']
            if timestamp.hour > 18: # Nächster Tag
                timestamp = datetime.datetime(timestamp.year, timestamp.month, timestamp.day+1, 6, 0, 0)
            df.loc[df['Fertigungsauf-tragsnummer'] == order_num, ['starttime']] = timestamp
            tool = row['Werkzeug-nummer']
            setup_time = calculate_setup_time(tool, last_tool)
            df.loc[df['Fertigungsauf-tragsnummer'] == order_num, ['setup_time']] = setup_time
            try:
                prod_time = int(row['Maschinen-laufzeit'])
            except:
                prod_time = 60
            runtime = prod_time + setup_time
            timestamp = timestamp + datetime.timedelta(minutes=runtime)
            order_num = row['Fertigungsauf-tragsnummer']
            df.loc[df['Fertigungsauf-tragsnummer'] == order_num, ['endtime']] = timestamp
            last_tool = tool
    return df
            
df = calculate_timestamps(df, datetime.datetime(2022, 3, 16, 6, 0, 0), 'A0 023')

# %%
def preprocess_part_nr(df):
    #df['part'] = df.apply(lambda row: row['Teilenummer'][:row['Teilenummer'].rfind('[A-Z]')],axis=1)
    df['part'] = df.apply(lambda row: re.findall("[0-9]+[A-Z]+", row['Teilenummer'])[-1], axis=1)
    return df

df = preprocess_part_nr(df)

# %%
df = df[['part', 'machine_id', 'starttime', 'endtime', 'setup_time']]
df
# Out:
#           part machine_id                 starttime                   endtime  \
# 0        60PAP       1531 2022-03-16 06:00:00+00:00 2022-03-16 11:23:00+00:00
# 1         70AA       1531 2022-03-16 11:23:00+00:00 2022-03-16 13:50:00+00:00
# 2        80PAK       1531 2022-03-16 13:50:00+00:00 2022-03-16 15:54:00+00:00
# 3        90APK       1531 2022-03-16 15:54:00+00:00 2022-03-16 17:38:00+00:00
# 4        55PAP       1535 2022-03-16 06:00:00+00:00 2022-03-16 15:45:00+00:00
# 5        55PAP       1535 2022-03-16 15:45:00+00:00 2022-03-16 17:00:00+00:00
# 6        55PAP       1536 2022-03-16 06:00:00+00:00 2022-03-16 07:08:00+00:00
# 7        55PAP       1537 2022-03-16 06:00:00+00:00 2022-03-16 06:57:00+00:00
# 8        80APK       1531 2022-03-16 17:38:00+00:00 2022-03-16 18:12:00+00:00
# 9        55PAP       1535 2022-03-16 17:00:00+00:00 2022-03-16 17:34:00+00:00
# 10       80APK       1531 2022-03-16 18:12:00+00:00 2022-03-16 18:31:00+00:00
# 11       80APK       1531 2022-03-16 18:31:00+00:00 2022-03-16 18:48:00+00:00
# 12       60APK       1533 2022-03-16 06:00:00+00:00 2022-03-16 06:30:00+00:00
# 13       70PAK       1531 2022-03-16 18:48:00+00:00 2022-03-16 23:36:00+00:00
# 14       75APK       1531 2022-03-17 06:00:00+00:00 2022-03-17 07:10:00+00:00
# 15       75APK       1531 2022-03-17 07:10:00+00:00 2022-03-17 07:48:00+00:00
# 16       75APK       1531 2022-03-17 07:48:00+00:00 2022-03-17 08:24:00+00:00
# 17      90PAPK       1531 2022-03-17 08:24:00+00:00 2022-03-17 09:28:00+00:00
# 18       70PAK       1531 2022-03-17 09:28:00+00:00 2022-03-17 11:02:00+00:00
# 19       75APK       1531 2022-03-17 11:02:00+00:00 2022-03-17 14:43:00+00:00
# 20        63AA       1531 2022-03-17 14:43:00+00:00 2022-03-17 15:13:00+00:00
# 21       60APK       1532 2022-03-16 06:00:00+00:00 2022-03-16 11:00:00+00:00
# 22       75APK       1531 2022-03-17 15:13:00+00:00 2022-03-17 16:02:00+00:00
# 23        50AA       1536 2022-03-16 07:08:00+00:00 2022-03-16 07:39:00+00:00
# 24       60APK       1533 2022-03-16 06:30:00+00:00 2022-03-16 10:33:00+00:00
# 25       75APK       1531 2022-03-17 16:02:00+00:00 2022-03-17 18:38:00+00:00
# 26       75APK       1531 2022-03-17 18:38:00+00:00 2022-03-17 19:12:00+00:00
# 27      90PAPK       1531 2022-03-18 06:00:00+00:00 2022-03-18 09:05:00+00:00
# 28       75APK       1531 2022-03-18 09:05:00+00:00 2022-03-18 09:56:00+00:00
# 29       65PAK       1531 2022-03-18 09:56:00+00:00 2022-03-18 10:30:00+00:00
# 30       75APK       1531 2022-03-18 10:30:00+00:00 2022-03-18 14:11:00+00:00
# 31       130AA       1531 2022-03-18 14:11:00+00:00 2022-03-18 14:42:00+00:00
# 32        70AA       1531 2022-03-18 14:42:00+00:00 2022-03-18 18:20:00+00:00
# 33       75APK       1531 2022-03-18 18:20:00+00:00 2022-03-18 20:07:00+00:00
# 34       75APK       1531 2022-03-19 06:00:00+00:00 2022-03-19 06:55:00+00:00
# 35        50AA       1537 2022-03-16 06:57:00+00:00 2022-03-16 12:18:00+00:00
# 36  60APPBEIGE       1533 2022-03-16 10:33:00+00:00 2022-03-16 11:48:00+00:00
# 37       40APK       1536 2022-03-16 07:39:00+00:00 2022-03-16 08:46:00+00:00
# 38        50AA       1535 2022-03-16 17:34:00+00:00 2022-03-16 18:20:00+00:00
# 39       55APK       1533 2022-03-16 11:48:00+00:00 2022-03-16 12:34:00+00:00
# 40       60PAK       1532 2022-03-16 11:00:00+00:00 2022-03-16 13:01:00+00:00
# 41      60PAPK       1533 2022-03-16 12:34:00+00:00 2022-03-16 14:55:00+00:00
# 42       55APK       1537 2022-03-16 12:18:00+00:00 2022-03-16 13:13:00+00:00
# 43        55AA       1536 2022-03-16 08:46:00+00:00 2022-03-16 09:17:00+00:00
# 44        50AA       1535 2022-03-16 18:20:00+00:00 2022-03-16 21:30:00+00:00
# 45        50AA       1533 2022-03-16 14:55:00+00:00 2022-03-16 15:26:00+00:00
# 46       60APK       1532 2022-03-16 13:01:00+00:00 2022-03-16 18:58:00+00:00
# 47       20AGA       1534 2022-03-16 06:00:00+00:00 2022-03-17 10:04:00+00:00
# 48       60APK       1533 2022-03-16 15:26:00+00:00 2022-03-16 16:43:00+00:00
# 49       45APK       1536 2022-03-16 09:17:00+00:00 2022-03-16 10:13:00+00:00
#
#     setup_time
# 0            0
# 1            0
# 2            0
# 3            0
# 4           15
# 5            0
# 6           15
# 7           15
# 8           15
# 9           15
# 10           0
# 11           0
# 12          15
# 13          15
# 14          15
# 15           0
# 16           0
# 17          15
# 18          15
# 19          15
# 20          15
# 21           0
# 22          15
# 23          15
# 24           0
# 25           0
# 26           0
# 27          15
# 28          15
# 29          15
# 30          15
# 31          15
# 32          15
# 33          15
# 34           0
# 35          15
# 36          15
# 37          15
# 38          15
# 39          15
# 40           0
# 41          15
# 42          15
# 43          15
# 44           0
# 45          15
# 46           0
# 47          15
# 48          15
# 49          15

# %% [markdown]
# # Pm4py

# %%
import pm4py
from pm4py.objects.log.util import dataframe_utils
from pm4py.objects.conversion.log import converter as log_converter

# %%
log_df = dataframe_utils.convert_timestamp_columns_in_df(df)
log_df = log_df.sort_values('starttime')
event_log = log_converter.apply(log_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [28], in <module>
#       1 log_df = dataframe_utils.convert_timestamp_columns_in_df(df)
#       2 log_df = log_df.sort_values('starttime')
# ----> 3 event_log = log_converter.apply(log_df)
#
# File D:\Anaconda3\envs\ki-marktplatz\lib\site-packages\pm4py\objects\conversion\log\converter.py:34, in apply(log, parameters, variant)
#      33 def apply(log, parameters=None, variant=Variants.TO_EVENT_LOG):
# ---> 34     return variant.value.apply(log, parameters=parameters)
#
# File D:\Anaconda3\envs\ki-marktplatz\lib\site-packages\pm4py\objects\conversion\log\variants\to_event_log.py:49, in apply(log, parameters)
#      47         log = to_event_stream.apply(log, parameters=parameters)
#      48 if isinstance(log, log_instance.EventStream) and (not isinstance(log, log_instance.EventLog)):
# ---> 49     return __transform_event_stream_to_event_log(log, case_glue=glue, include_case_attributes=True,
#      50                                                  case_attribute_prefix=case_pref, enable_deepcopy=enable_deepcopy)
#      51 return log
#
# File D:\Anaconda3\envs\ki-marktplatz\lib\site-packages\pm4py\objects\conversion\log\variants\to_event_log.py:85, in __transform_event_stream_to_event_log(log, case_glue, include_case_attributes, case_attribute_prefix, enable_deepcopy)
#      83 for orig_event in log:
#      84     event = copy(orig_event)
# ---> 85     glue = event[case_glue]
#      86     if glue not in traces:
#      87         trace_attr = {}
#
# File D:\Anaconda3\envs\ki-marktplatz\lib\site-packages\pm4py\objects\log\obj.py:60, in Event.__getitem__(self, key)
#      59 def __getitem__(self, key):
# ---> 60     return self._dict[key]
#
# KeyError: 'case:concept:name'
